# %%
# from turtle import *
import ipyturtle3 as turtle
from ipyturtle3 import hold_canvas
from time import sleep

# %%
def turtle_tree(branch_len, turtle):
    # 1.先向右拐到底
    # 2.尝试第一次向左画，长度小于设置的值，因此调整角度后退到上一节点（每次回退到上一节点，也就是回到上一次递归调用函数的下一条语句处）
    # 3.退到上一节点后，向左前进，然后继续向右
    # 总结：先画右子树，再画左子树
    print(f"本轮次需要操作的长度为{branch_len}")
    if branch_len > 5:
        turtle.forward(branch_len)
        #print(f"前进{branch_len}")

        turtle.right(20)
        #input("前画笔向右20")
        turtle_tree(branch_len - 15, turtle)

        turtle.left(40)
        #input("画笔向左40")
        turtle_tree(branch_len - 15, turtle)

        turtle.right(20)
        #input("后画笔向右20")
        turtle.backward(branch_len)
        #input(f"后退{branch_len}")

# %%
import ipyturtle3 as turtle
from ipyturtle3 import hold_canvas

# 创建一个画布
myCanvas=turtle.Canvas(width=500,height=250)
display(myCanvas)

# 创建一个海龟屏幕，它是海龟绘图的容器
myTS=turtle.TurtleScreen(myCanvas)
myTS.clear()  # 清除屏幕
myTS.bgcolor("lightgreen")  # 设置背景颜色为浅绿色
# Out:
# Canvas(height=250, width=500)

# %%
t = turtle.Turtle(myTS) # 创建一个海龟
display(myCanvas) # 显示画布
# Out:
# Canvas(height=250, width=500)

# %%
display(myCanvas) # 显示画布
t.left(90)
turtle_tree(46, t)
# Out:
# Canvas(height=250, width=500)
# 本轮次需要操作的长度为46
# 本轮次需要操作的长度为31
# 本轮次需要操作的长度为16
# 本轮次需要操作的长度为1
# 本轮次需要操作的长度为1
# 本轮次需要操作的长度为16
# 本轮次需要操作的长度为1
# 本轮次需要操作的长度为1
# 本轮次需要操作的长度为31
# 本轮次需要操作的长度为16
# 本轮次需要操作的长度为1
# 本轮次需要操作的长度为1
# 本轮次需要操作的长度为16
# 本轮次需要操作的长度为1
# 本轮次需要操作的长度为1

# %%
myCanvas1=turtle.Canvas(width=500,height=500)

# 创建一个海龟屏幕，它是海龟绘图的容器
myTS1=turtle.TurtleScreen(myCanvas1)
myTS1.clear()  # 清除屏幕
myTS1.bgcolor("lightgreen")  # 设置背景颜色为浅绿色

t1 = turtle.Turtle(myTS1) # 创建一个海龟
display(myCanvas1) # 显示画布
# Out:
# Canvas(width=500)

# %%
t1.left(90)
t1.up()
t1.backward(233)
t1.down()
t1.color('green')
turtle_tree(110, t1)
# Out:
# 本轮次需要操作的长度为110
# 本轮次需要操作的长度为95
# 本轮次需要操作的长度为80
# 本轮次需要操作的长度为65
# 本轮次需要操作的长度为50
# 本轮次需要操作的长度为35
# 本轮次需要操作的长度为20
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为20
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为35
# 本轮次需要操作的长度为20
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为20
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为50
# 本轮次需要操作的长度为35
# 本轮次需要操作的长度为20
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为20
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为35
# 本轮次需要操作的长度为20
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为20
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为65
# 本轮次需要操作的长度为50
# 本轮次需要操作的长度为35
# 本轮次需要操作的长度为20
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为20
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为35
# 本轮次需要操作的长度为20
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为20
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为50
# 本轮次需要操作的长度为35
# 本轮次需要操作的长度为20
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为20
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为35
# 本轮次需要操作的长度为20
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为5
# 本轮次需要操作的长度为20
# 本轮次需要操作的长度为5
# ...
